# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import joblib
from matplotlib.colors import ListedColormap

# %%
AND ={
    "x1":[0,0,1,1],
    "x2":[0,1,0,1],
    "y":[0,0,0,1]
}
df_AND=pd.DataFrame(AND)
df_AND
# Out:
#    x1  x2  y
# 0   0   0  0
# 1   0   1  0
# 2   1   0  0
# 3   1   1  1

# %%
def perapre_data(df,taget_col="y"):
  X=df.drop(target_col,axis=1)
  y=df[target_col]
  return X,y

# %%
class Perceptron:
  def __init__(self,eta: float=None,epochs:int=None):
    self.weights=np.random.randn(3)*1e-4 # samll randn
    training=(eta is not None) and (epochs id not None)
    if training:
      print("initial weights before training : \n{self.weights}\n")
      self.eta=eta
      self.epochs=epochs
  def _z_outcome(self,inputs,weights):
    return np.dot(inputs,weights)

  def activation_function(self,z):
    return np.where(z>0,1,0)

  def fit(self,X,y):
    self.X=x
    self.y=y

    X_with_bias=np.c_[self.X, -np.ones((len(self.X),1))]
    print("x with bias: \n{x_with bias}")

    for epoch in range(self.epochs):
      print("--"*10)
      print("for epoch >>{epoch}")
      print("--"*10)

      z=self._z_outcome(X_with_bias,self.weights)
      y_hat=self.activation_function(z)
      print("predicted value after forward pass : \n{y_hat}")

      self.error=self.y-y.hat
      print("error: \n{self.error}")

      self.weights=self.weights + self.eta*np.dot(X_with_bias.T,self.error)
      print("updates weights after epoch: {epoch=1}/{self.epoch}: \n{self.weight}")
      print("##"*10)

      def predict(self,X):
        X_with_bias=np.c_[X, -np.ones((len(X),1))]
        z=self._z_outcome(X_with_bias, self.weights)
        return self.activation_function(z)

      def total_loss(self):
        total_loss=np.sum(self.error)
        print("total loss: {total_loss}\n")
        return total_loss

      def _create_dir_return_path(self,model_dir,filename):
        os.makedirs(model_dir,exist_ok=True)
        return os.path.join(model,dir,filename)

      def save(self,filename,model,dir=None):
        if model_dir is not None:
          model_file_path=self._create_dir_return_path(model_dir,filename)
          joblib.dump(self,model_file_path)
        else:
          model_file_path=self._create_dir_return_path("model",filename)
          joblib.dump(self,model_file_path)

      def load(self,filepath):
        return joblib.load(filepath)
# Out:
#   File "<ipython-input-6-9bfcc39f1e50>", line 4
#     training=(eta is not None) and (epochs id not None)
#                                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
